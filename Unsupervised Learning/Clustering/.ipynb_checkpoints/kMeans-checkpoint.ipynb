# %% [markdown]
# # K Means Clustering Algorithm Implementation

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.datasets import make_moons
import pandas as pd
import numpy as np

# %%
x, y = make_blobs(n_samples=1000,centers=3,n_features=2,random_state=23)

# %%
plt.scatter(x[:,0],x[:,1],c=y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=y_train)

# %%
plt.scatter(x_test[:,0],x_test[:,1],c=y_test)

# %%
from sklearn.cluster import KMeans

# %%
## manual process
## elbow method to select the k value

wcss = []
for k in range(1,100):
    kmeans = KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x_train)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [34827.57682552021,
#  7935.4372861454185,
#  1319.2730531585605,
#  1171.5031490581139,
#  1071.8957738433837,
#  866.4433782572448,
#  773.1138259202514,
#  687.8028472424064,
#  582.7353938427458,
#  598.3160664028859,
#  515.598346069097,
#  463.4610517926487,
#  451.39966506495404,
#  405.60230762278894,
#  416.6445512540075,
#  365.28889330070274,
#  338.3482649767369,
#  330.28604430183003,
#  294.49697396545326,
#  286.4820824488894,
#  268.91419881944034,
#  264.978461862077,
#  253.0897720285075,
#  232.14384022602482,
#  233.10544906900947,
#  231.81840879008527,
#  220.10852915643898,
#  209.89804989333294,
#  197.91424061214155,
#  191.3317875250395,
#  191.223240380355,
#  185.02783761201226,
#  174.30277120663186,
#  168.69635049311594,
#  159.0090999188018,
#  163.88553817379278,
#  154.52765581253317,
#  147.9474898260852,
#  147.51888959914183,
#  141.06156955208928,
#  135.84858448625536,
#  135.91173290268688,
#  127.47936094156032,
#  122.23675583839699,
#  128.20275014940466,
#  119.94323046317149,
#  107.81711145007762,
#  116.6758601994546,
#  112.78085106543953,
#  108.8514824164016,
#  102.64674475858438,
#  103.11109290721903,
#  101.98055016909905,
#  99.27147648114891,
#  96.42188044854323,
#  93.06429254076268,
#  98.55025078852337,
#  94.58987824397478,
#  88.20057832540665,
#  86.34236907738914,
#  83.3497403251164,
#  84.68887043740052,
#  82.59356379748166,
#  83.51541717849454,
#  79.76247762614229,
#  75.22401169157928,
#  76.65445187623139,
#  73.3393073332569,
#  72.87421280894087,
#  72.93073369922884,
#  71.29428782161256,
#  68.66366395387804,
#  68.2409235397904,
#  67.2138689599054,
#  67.57329287981823,
#  64.35718031439475,
#  63.69993862204621,
#  64.56629399670635,
#  63.70566342946924,
#  60.65959156495464,
#  60.15639698079096,
#  58.73247885392099,
#  58.47222138103609,
#  57.0515393830419,
#  57.215249259258094,
#  57.72229421292328,
#  55.39282646007886,
#  53.58187937009082,
#  52.85850339118218,
#  53.0777156424861,
#  52.49673726494606,
#  50.146905520224884,
#  51.94983000395477,
#  48.84377997964309,
#  49.1062827310598,
#  49.093514717963586,
#  48.46533842054635,
#  48.09587199526007,
#  45.718226195479154]

# %%
plt.plot(range(1,100),wcss)
plt.xticks(range(1,100,10))
plt.xlabel("no of clusters")
plt.ylabel("intertia")
# Out:
# Text(0, 0.5, 'intertia')

# %%
kmeans = KMeans(n_clusters=3,init="k-means++")

# %%
y_labels = kmeans.fit_predict(x_train)

# %%
plt.scatter(x_train[:,0],x_train[:,1],c=y_labels)

# %%
y_test_labels = kmeans.predict(x_test)

# %%
plt.scatter(x_test[:,0],x_test[:,1],c=y_test_labels)

# %%
## automation with finding elbow or k value
# !pip install kneed
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kneed in c:\users\zisha\appdata\roaming\python\python314\site-packages (0.8.5)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\zisha\appdata\roaming\python\python314\site-packages (from kneed) (2.4.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\zisha\appdata\roaming\python\python314\site-packages (from kneed) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kneed import KneeLocator

# %%
kl = KneeLocator(range(1,100),wcss,curve="convex",direction="decreasing")

# %%
kl.elbow
# Out:
# np.int64(3)

# %%
## performace matrix

from sklearn.metrics import silhouette_score

# %%
silhouette_coeff = []

# %%
for k in range(2,11):
    kmeans = KMeans(n_clusters=k,init="k-means++")
    kmeans.fit(x_train)
    silhouette_coeff.append(silhouette_score(x_train,kmeans.labels_))

# %%
silhouette_coeff
# Out:
# [0.7281443868598331,
#  0.8071181203797672,
#  0.6419605021469034,
#  0.5054333080575093,
#  0.475072597890326,
#  0.33910884527822077,
#  0.3427542763753242,
#  0.33807088409350516,
#  0.3343202116701764]

# %%
plt.plot(range(2,11),silhouette_coeff)
plt.xlabel("cluster")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')
