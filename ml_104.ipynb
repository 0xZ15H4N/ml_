# %% [markdown]
# # Logistic Regression with scikit-learn

# %% [markdown]
# logistic regression focuses on predicting probabilities rather than direct values. It models how changes in independent variables affect the odds of an event occurring.
